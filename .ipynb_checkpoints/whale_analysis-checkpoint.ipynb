# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
#Set file paths
whale_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\whale_returns.csv")
algo_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\algo_returns.csv")
sp_tsx_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\sp_tsx_history.csv")

# %%
# Read CSV files into individual DataFrames and set the 'date' column as a datetime index
whale_df = pd.read_csv(whale_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df = pd.read_csv(algo_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp_tsx_df = pd.read_csv(sp_tsx_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# Sort the date index in ascending order
whale_df = whale_df.sort_index()
algo_df = algo_df.sort_index()
sp_tsx_df = sp_tsx_df.sort_index()

# %%
# Reading whale returns
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna().copy()

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna().copy()

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_tsx_df["Close"].dtype
# Out:
# dtype('O')

# %%
# Fix Data Types
sp_tsx_df["Close"] = sp_tsx_df["Close"].str.replace("$", "")
sp_tsx_df["Close"] = sp_tsx_df["Close"].str.replace(",", "")
sp_tsx_df["Close"] = sp_tsx_df["Close"].astype('float')
sp_tsx_df.head()
# Out:
# C:\Users\User\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
sp_tsx_daily_return = sp_tsx_df.pct_change()
sp_tsx_daily_return.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_tsx_daily_return = sp_tsx_daily_return.dropna().copy()
sp_tsx_daily_return.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_daily_return = sp_tsx_daily_return.rename(columns={
    "Close":"S&P TSX"})
sp_tsx_daily_return.head()
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns = pd.concat([whale_df, algo_df, sp_tsx_daily_return], axis="columns", join="inner")
combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_return = (1+combined_returns).cumprod()-1
# Plot cumulative returns
cumulative_return.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Does any portfolio outperform the S&P TSX 60?
# Answer: As can be seen from the above graph, the following portfolios outperform the S&P TSX 60:
        # Soros Fund Management LLC
        # Berkshire Hathaway Inc
        # Algo 1
        # Algo 2

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_returns_sd = combined_returns.std().sort_values(ascending = True)
print(f"Standard deviation for each portfolio is as under (in ascending order): \n{combined_returns_sd}")
# Out:
# Standard deviation for each portfolio is as under (in ascending order):
# PAULSON & CO.INC.              0.006982
# S&P TSX                        0.007034
# Algo 1                         0.007589
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 2                         0.008326
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Determine which portfolios are riskier than the S&P TSX 60
# Answer: As can be seen from the above standard deviation results for each portfolio, the following portfolios are riskier than the S&P TSX 60:
        # Algo 1
        # Soros Fund Management LLC
        # Algo 2
        # Tiger Global Management LLC
        # Berkshire Hathaway Inc

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualised_sd = combined_returns_sd*np.sqrt(252)
print(f"Annualised standard deviation for each portfolio is as under:\n{annualised_sd}")
# Out:
# Annualised standard deviation for each portfolio is as under:
# PAULSON & CO.INC.              0.110841
# S&P TSX                        0.111664
# Algo 1                         0.120470
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 2                         0.132177
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation
combined_returns.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
combined_returns_correlation = combined_returns.corr()
# Display the correlation matrix
combined_returns_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# S&P TSX                                       0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %%
# Display the correlation matrix heatmap
sns.heatmap(combined_returns_correlation, vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %%
# Which portfolios mimic the S&P TSX 60?
# Answer: Considering the above heatmap and correlation results, Algo 2 portfolio's correlation to S&P TSX 60 is the highest, Algo 2 closest mimics the S&P TSX 60.

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Choose one portfolio, then calculate and plot the 60-day rolling beta between that portfolio and the S&P TSX 60.
# Chosen portfolio: Algo 1

# %%
# Calculate covariance of a single portfolio
algo1_covariance = combined_returns["Algo 1"].cov(combined_returns["S&P TSX"])
# Calculate variance of S&P TSX
index_variance = combined_returns["S&P TSX"].var()
# Computing beta
algo1_beta = algo1_covariance/index_variance
# Plot beta trend
rolling_algo1_covariance = combined_returns["Algo 1"].rolling(window=60).cov(combined_returns["S&P TSX"])
rolling_index_variance = combined_returns["S&P TSX"].rolling(window=60).var()
rolling_algo1_beta = rolling_algo1_covariance/rolling_index_variance
ax = rolling_index_variance.plot(figsize=(20,10), title="60-day rolling beta between Algo 1 and the S&P TSX 60")
rolling_algo1_beta.plot(ax=ax)
ax.legend(["S&P TSX 60", "Algo 1"])

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_returns.ewm(halflife=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratio = ((combined_returns.mean()*252)/(combined_returns.std()*np.sqrt(252)))
print (f"The Sharpe Ratio for each portfolio is as under:\n{sharpe_ratio}")
# Out:
# The Sharpe Ratio for each portfolio is as under:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P TSX                        0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot.bar (title="Sharpe Ratios for each portfolio")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios for each portfolio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Answer: Assessing the performance of the algorithmic strategies solely based on Sharpe Ratios, it can be seen that both the algorithmic strategies outperformed the S&P TSX 60 and most of the whale portfolios.  However, Berkshire Hathaway Inc's portfolio performs better than Algo 2's strategy since Berkshire Hathaway Inc's Sharpe Ratio is slightly higher than that of Algo 2's Sharpe Ratio.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
l_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\l_historical.csv")
l_df = pd.read_csv(l_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
l_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
# Reading data from 2nd stock
otex_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\otex_historical.csv")
otex_df = pd.read_csv(otex_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
otex_df.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
# Reading data from 3rd stock
shop_path = Path(r"C:\Users\User\Documents\Manan Wala\Fintech bootcamp\Homework\Homework_3\Resources\shop_historical.csv")
shop_df = pd.read_csv(shop_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
shop_df.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Combine all stocks in a single DataFrame
combined_df = pd.concat([l_df, otex_df, shop_df], axis="columns", join="inner")
combined_df.head()
# Out:
#            Symbol  Close Symbol  Close Symbol   Close
# Date
# 2018-01-02      L  57.99   OTEX  43.58   SHOP  132.06
# 2018-01-03      L  57.41   OTEX  43.07   SHOP  135.15
# 2018-01-04      L  57.42   OTEX  42.91   SHOP  137.46
# 2018-01-05      L  57.42   OTEX  42.57   SHOP  137.26
# 2018-01-08      L  56.86   OTEX  42.16   SHOP  139.51

# %%
# Reset Date index
combined_df = combined_df.reset_index()
combined_df.head()
# Out:
#         Date Symbol  Close Symbol  Close Symbol   Close
# 0 2018-01-02      L  57.99   OTEX  43.58   SHOP  132.06
# 1 2018-01-03      L  57.41   OTEX  43.07   SHOP  135.15
# 2 2018-01-04      L  57.42   OTEX  42.91   SHOP  137.46
# 3 2018-01-05      L  57.42   OTEX  42.57   SHOP  137.26
# 4 2018-01-08      L  56.86   OTEX  42.16   SHOP  139.51

# %%
# Reorganize portfolio data by having a column per symbol - dropping unnecessary columns
combined_df = combined_df.drop(columns=["Symbol", "Symbol", "Symbol"])
combined_df.head()
# Out:
#         Date  Close  Close   Close
# 0 2018-01-02  57.99  43.58  132.06
# 1 2018-01-03  57.41  43.07  135.15
# 2 2018-01-04  57.42  42.91  137.46
# 3 2018-01-05  57.42  42.57  137.26
# 4 2018-01-08  56.86  42.16  139.51

# %%
# Reorganize portfolio data by having a column per symbol - renaming columns
columns = ["Date", "L", "OTEX", "SHOP"]
combined_df.columns = columns
combined_df.head()
# Out:
#         Date      L   OTEX    SHOP
# 0 2018-01-02  57.99  43.58  132.06
# 1 2018-01-03  57.41  43.07  135.15
# 2 2018-01-04  57.42  42.91  137.46
# 3 2018-01-05  57.42  42.57  137.26
# 4 2018-01-08  56.86  42.16  139.51

# %%
combined_df = combined_df.set_index("Date")
combined_df.head()
# Out:
#                 L   OTEX    SHOP
# Date
# 2018-01-02  57.99  43.58  132.06
# 2018-01-03  57.41  43.07  135.15
# 2018-01-04  57.42  42.91  137.46
# 2018-01-05  57.42  42.57  137.26
# 2018-01-08  56.86  42.16  139.51

# %%
# Calculate daily returns
daily_returns = combined_df.pct_change()
# Drop NAs
daily_returns = daily_returns.dropna()
# Display sample data
daily_returns.head()
# Out:
#                    L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_returns.dot(weights)
# Display sample data
portfolio_returns.head()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_returns_2 = pd.concat([combined_returns, portfolio_returns], axis="columns", join="inner")
combined_returns_2 = combined_returns_2.rename(columns={0:"Custom Portfolio"})
combined_returns_2.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2   S&P TSX  Custom Portfolio
# Date
# 2018-01-03  0.008175  0.003774          0.000565
# 2018-01-04  0.004294  0.002528          0.004517
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_returns_2 = combined_returns_2.dropna().copy()
combined_returns_2.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2   S&P TSX  Custom Portfolio
# Date
# 2018-01-03  0.008175  0.003774          0.000565
# 2018-01-04  0.004294  0.002528          0.004517
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the standard deviation
combined_returns_2_sd = combined_returns_2.std().sort_values(ascending=True)
combined_returns_2_sd.head()
# Out:
# S&P TSX                      0.006244
# PAULSON & CO.INC.            0.007203
# Algo 1                       0.007561
# Algo 2                       0.008672
# SOROS FUND MANAGEMENT LLC    0.009177
# dtype: float64

# %%
# Calculate the annualized `std`
annualised_combined_returns_2_sd = combined_returns_2_sd*np.sqrt(252)
print(f"Annualised standard deviation for each portfolio is as under:\n{annualised_combined_returns_2_sd}")
# Out:
# Annualised standard deviation for each portfolio is as under:
# S&P TSX                        0.099121
# PAULSON & CO.INC.              0.114343
# Algo 1                         0.120028
# Algo 2                         0.137664
# SOROS FUND MANAGEMENT LLC      0.145675
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# Custom Portfolio               0.224346
# BERKSHIRE HATHAWAY INC         0.227445
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
combined_returns_2.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_returns_2_correlation = combined_returns_2.corr()
combined_returns_2_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.764174
# PAULSON & CO.INC.                             0.764174            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.526710            0.536534
# BERKSHIRE HATHAWAY INC                        0.782414            0.647407
# Algo 1                                        0.305525            0.320568
# Algo 2                                        0.834431            0.797494
# S&P TSX                                       0.686681            0.623728
# Custom Portfolio                              0.556093            0.385305
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.526710
# PAULSON & CO.INC.                               0.536534
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.384316
# ...

# %%
# Plot the correlation on heatmap
sns.heatmap(combined_returns_2_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta

# %%
# Calculate the covariance of custom portfolio
custom_covariance = combined_returns_2["Custom Portfolio"].cov(combined_returns_2["S&P TSX"])

# %%
# Calculate the variance of the S&P TSX 60 index
sp_tsx_variance = combined_returns_2["S&P TSX"].var()

# %%
# Calculate the Beta for custom portfolio
custom_beta = custom_covariance/sp_tsx_variance

# %%
# Calculate and plot rolling beta
rolling_custom_covariance = combined_returns_2["Custom Portfolio"].rolling(window=60).cov(combined_returns_2["S&P TSX"])
rolling_sp_tsx_variance = combined_returns_2["S&P TSX"].rolling(window=60).var()
rolling_custom_beta = rolling_custom_covariance/rolling_sp_tsx_variance
ax = rolling_sp_tsx_variance.plot(figsize=(20,10), title="60-day rolling beta between Custom Portfolio and the S&P TSX 60")
rolling_custom_beta.plot(ax=ax)
ax.legend(["S&P TSX 60", "Custom Portfolio"])

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios_2 = ((combined_returns_2.mean()*252)/(combined_returns_2.std()*np.sqrt(252)))
print (f"The Sharpe Ratio for each portfolio is as under:\n{sharpe_ratios_2}")
# Out:
# The Sharpe Ratio for each portfolio is as under:
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# S&P TSX                        0.034651
# Custom Portfolio               1.564547
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_2.plot.bar(title="Sharpe Ratio for each portfolio")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio for each portfolio'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Answer: Assessing the performance of the custom portfolio solely based on Sharpe Ratios, it can be seen that the custom portfolio outperformed the S&P TSX 60 and most of the whale portfolios, except Algo 1. The algorithmic strategy for Algo 1 outperformed the S&P TSX 60 as well as all portfolios considered here.
